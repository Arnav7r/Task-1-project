# %% [markdown]
# Company Dataset

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\raiar\onedrive\documents\github\task-1-project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("people-100000.csv")

# %%
df.drop_duplicates(df)
# Out:
#         Index          User Id First Name Last Name     Sex  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2           3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3           4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4           5  9C4Df1246ddf543     Angela      Shea    Male
# ...       ...              ...        ...       ...     ...
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# 2         johnnybooker@example.org  001-149-154-0679x1617    2018-02-10
# 3                wkhan@example.org     870.294.7563x20939    1938-06-14
# 4       reginaldgarner@example.com           242.442.2978    1971-11-22
# ...                            ...                    ...           ...
# 99995  zacharygalloway@example.net       971-408-5795x791    2015-09-02
# 99996            qkane@example.org   001-183-966-1623x446    1978-01-30
# 99997          jenny91@example.com             3010820886    1939-07-11
# 99998          imcneil@example.com          (753)522-4673    1942-02-05
# 99999             emay@example.net       357.974.5692x909    1918-05-30
#
#                                 Job Title
# 0                 Teacher, primary school
# 1           Development worker, community
# 2                       Ceramics designer
# 3              Civil engineer, consulting
# 4               Health and safety adviser
# ...                                   ...
# 99995                   Designer, graphic
# 99996                      Cytogeneticist
# 99997               Engineering geologist
# 99998             Clinical cytogeneticist
# 99999  Teacher, special educational needs
#
# [100000 rows x 9 columns]

# %%
df.dropna(subset=["Phone"], inplace=True)

# %%
df.dtypes
# Out:
# Index                     int64
# User Id                  object
# First Name               object
# Last Name                object
# Sex                      object
# Email                    object
# Phone                    object
# Date of birth    datetime64[ns]
# Job Title                object
# dtype: object

# %%
df["Date of birth"] = pd.to_datetime(
    df["Date of birth"],
    errors="coerce",
    dayfirst=True
)
df["Date of birth"] = df["Date of birth"].dt.strftime("%d-%m-%Y")

# %%
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
df["Phone"] = df["Phone"].astype(str)

# %%
df["Phone"] = df["Phone"].str.replace(r"\D", "", regex=True)

# %%
df["Sex"] = df["Sex"].replace({"Male": "M", "Female": "F"})

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name Sex  \
# 0      1  e09c4f4cbfEFaFd       Dawn   Trevino   M
# 1      2  D781D28b845Ab9D       Dale  Mcknight   M
# 2      3  eda7EcaF87b2D80    Herbert      Bean   F
# 3      4  E75ACea5D7AeC3e      Karen   Everett   F
# 4      5  9C4Df1246ddf543     Angela      Shea   M
#
#                         Email              Phone Date of birth  \
# 0     clintongood@example.org         3604235286    17-01-1972
# 1  clairebradshaw@example.org         9062423229    31-01-1931
# 2    johnnybooker@example.org  00114915406791617    10-02-2018
# 3           wkhan@example.org    870294756320939    14-06-1938
# 4  reginaldgarner@example.com         2424422978    22-11-1971
#
#                        Job Title
# 0        Teacher, primary school
# 1  Development worker, community
# 2              Ceramics designer
# 3     Civil engineer, consulting
# 4      Health and safety adviser
